# %%
import pandas as pd

# %%
response = pd.read_csv('marshall-islands-taiwan.csv')
marshall = pd.DataFrame(response)
marshall
# Out:
#     Year ROC Capital Grants (Projects?) Grants (Tax-Free?) Scholarship  \
# 0   2013                            NaN                NaN         NaN
# 1   2014                            NaN                NaN         NaN
# 2   2015                   $7.4 million       $3.6 million         NaN
# 3   2016                   $7.4 million       $3.6 million         NaN
# 4   2017                   $7.4 million       $3.6 million         NaN
# 5   2018                   $7.4 million       $3.6 million         NaN
# 6   2019                     $8 million         $4 million  $1 million
# 7   2020                     $8 million                NaN         NaN
# 8   2021                     $8 million                NaN         NaN
# 9   2022                     $8 million         $4 million         NaN
# 10  2023                            NaN                NaN         NaN
#
#           Total                                              Notes
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2   $11 million  I am confused by this accounting system (what ...
# 3   $11 million                                                NaN
# 4   $11 million                                                NaN
# 5   $11 million                                                NaN
# 6   $13 million                                                NaN
# 7    $8 million     $8 million swapped from third to second column
# 8    $8 million  8 mil in 'expenditures' and 8 mil in revenue…h...
# 9   $12 million  Another $8 million listed as 'Capital Grants' ...
# 10          NaN                                                NaN

# %%
# marshall = marshall.drop([0])
# marshall

# %%
# marshall = marshall.drop([1])

# %%
marshall
# Out:
#     Year ROC Capital Grants (Projects?) Grants (Tax-Free?) Scholarship  \
# 0   2013                            NaN                NaN         NaN
# 1   2014                            NaN                NaN         NaN
# 2   2015                   $7.4 million       $3.6 million         NaN
# 3   2016                   $7.4 million       $3.6 million         NaN
# 4   2017                   $7.4 million       $3.6 million         NaN
# 5   2018                   $7.4 million       $3.6 million         NaN
# 6   2019                     $8 million         $4 million  $1 million
# 7   2020                     $8 million                NaN         NaN
# 8   2021                     $8 million                NaN         NaN
# 9   2022                     $8 million         $4 million         NaN
# 10  2023                            NaN                NaN         NaN
#
#           Total                                              Notes
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2   $11 million  I am confused by this accounting system (what ...
# 3   $11 million                                                NaN
# 4   $11 million                                                NaN
# 5   $11 million                                                NaN
# 6   $13 million                                                NaN
# 7    $8 million     $8 million swapped from third to second column
# 8    $8 million  8 mil in 'expenditures' and 8 mil in revenue…h...
# 9   $12 million  Another $8 million listed as 'Capital Grants' ...
# 10          NaN                                                NaN

# %%
marshall = marshall.drop([10])
marshall
# Out:
#    Year ROC Capital Grants (Projects?) Grants (Tax-Free?) Scholarship  \
# 0  2013                            NaN                NaN         NaN
# 1  2014                            NaN                NaN         NaN
# 2  2015                   $7.4 million       $3.6 million         NaN
# 3  2016                   $7.4 million       $3.6 million         NaN
# 4  2017                   $7.4 million       $3.6 million         NaN
# 5  2018                   $7.4 million       $3.6 million         NaN
# 6  2019                     $8 million         $4 million  $1 million
# 7  2020                     $8 million                NaN         NaN
# 8  2021                     $8 million                NaN         NaN
# 9  2022                     $8 million         $4 million         NaN
#
#          Total                                              Notes
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2  $11 million  I am confused by this accounting system (what ...
# 3  $11 million                                                NaN
# 4  $11 million                                                NaN
# 5  $11 million                                                NaN
# 6  $13 million                                                NaN
# 7   $8 million     $8 million swapped from third to second column
# 8   $8 million  8 mil in 'expenditures' and 8 mil in revenue…h...
# 9  $12 million  Another $8 million listed as 'Capital Grants' ...

# %%
marshall = marshall.drop(['Notes'], axis=1)

# %%
marshall['grants'] = (marshall['ROC Capital Grants (Projects?)']
                                              .str.replace("$","")
                                              .str.replace("million","")
)
marshall
# Out:
#    Year ROC Capital Grants (Projects?) Grants (Tax-Free?) Scholarship  \
# 0  2013                            NaN                NaN         NaN
# 1  2014                            NaN                NaN         NaN
# 2  2015                   $7.4 million       $3.6 million         NaN
# 3  2016                   $7.4 million       $3.6 million         NaN
# 4  2017                   $7.4 million       $3.6 million         NaN
# 5  2018                   $7.4 million       $3.6 million         NaN
# 6  2019                     $8 million         $4 million  $1 million
# 7  2020                     $8 million                NaN         NaN
# 8  2021                     $8 million                NaN         NaN
# 9  2022                     $8 million         $4 million         NaN
#
#          Total grants
# 0          NaN    NaN
# 1          NaN    NaN
# 2  $11 million   7.4
# 3  $11 million   7.4
# 4  $11 million   7.4
# 5  $11 million   7.4
# 6  $13 million     8
# 7   $8 million     8
# 8   $8 million     8
# 9  $12 million     8

# %%
marshall['other'] = (marshall['Grants (Tax-Free?)']
                    .str.replace("$","")
                    .str.replace("million","")
                     .str.replace("NaN",'0')
                    )
marshall
# Out:
#    Year ROC Capital Grants (Projects?) Grants (Tax-Free?) Scholarship  \
# 0  2013                            NaN                NaN         NaN
# 1  2014                            NaN                NaN         NaN
# 2  2015                   $7.4 million       $3.6 million         NaN
# 3  2016                   $7.4 million       $3.6 million         NaN
# 4  2017                   $7.4 million       $3.6 million         NaN
# 5  2018                   $7.4 million       $3.6 million         NaN
# 6  2019                     $8 million         $4 million  $1 million
# 7  2020                     $8 million                NaN         NaN
# 8  2021                     $8 million                NaN         NaN
# 9  2022                     $8 million         $4 million         NaN
#
#          Total grants other
# 0          NaN    NaN   NaN
# 1          NaN    NaN   NaN
# 2  $11 million   7.4   3.6
# 3  $11 million   7.4   3.6
# 4  $11 million   7.4   3.6
# 5  $11 million   7.4   3.6
# 6  $13 million     8     4
# 7   $8 million     8    NaN
# 8   $8 million     8    NaN
# 9  $12 million     8     4

# %%
marshall = marshall.fillna(0)

# %%
marshall.drop(['ROC Capital Grants (Projects?)'], axis=1)
marshall.drop(['Grants (Tax-Free?)'], axis=1, inplace=True)
marshall.drop(['Total'], axis=1, inplace=True)
marshall
# Out:
#    Year ROC Capital Grants (Projects?) Scholarship grants other
# 0  2013                              0           0      0     0
# 1  2014                              0           0      0     0
# 2  2015                   $7.4 million           0   7.4   3.6
# 3  2016                   $7.4 million           0   7.4   3.6
# 4  2017                   $7.4 million           0   7.4   3.6
# 5  2018                   $7.4 million           0   7.4   3.6
# 6  2019                     $8 million  $1 million     8     4
# 7  2020                     $8 million           0     8      0
# 8  2021                     $8 million           0     8      0
# 9  2022                     $8 million           0     8     4

# %%
marshall['scholarship'] = (marshall['Scholarship']
                           .str.replace("$","")
                           .str.replace("million","")
)
marshall = marshall.drop(['Scholarship'], axis=1)
marshall = marshall.fillna(0)
marshall
# Out:
#    Year ROC Capital Grants (Projects?) grants other scholarship
# 0  2013                              0      0     0           0
# 1  2014                              0      0     0           0
# 2  2015                   $7.4 million   7.4   3.6            0
# 3  2016                   $7.4 million   7.4   3.6            0
# 4  2017                   $7.4 million   7.4   3.6            0
# 5  2018                   $7.4 million   7.4   3.6            0
# 6  2019                     $8 million     8     4           1
# 7  2020                     $8 million     8      0           0
# 8  2021                     $8 million     8      0           0
# 9  2022                     $8 million     8     4            0

# %%
marshall['total'] = marshall.grants.astype(float) + marshall.other.astype(float) + marshall.scholarship.astype(float)
marshall.drop(['ROC Capital Grants (Projects?)'], axis=1, inplace=True)
marshall
# Out:
#    Year grants other scholarship  total
# 0  2013      0     0           0    0.0
# 1  2014      0     0           0    0.0
# 2  2015   7.4   3.6            0   11.0
# 3  2016   7.4   3.6            0   11.0
# 4  2017   7.4   3.6            0   11.0
# 5  2018   7.4   3.6            0   11.0
# 6  2019     8     4           1    13.0
# 7  2020     8      0           0    8.0
# 8  2021     8      0           0    8.0
# 9  2022     8     4            0   12.0

# %%
marshall.to_csv('marshall_clean.csv')

# %%
nauru = pd.read_csv('nauru-taiwan.csv')
nauru
# Out:
#     Year   Grants (USD) Grants In Kind (USD)          Total
# 0   2013   $9.3 million                  NaN   $9.3 million
# 1   2014   $9.3 million                  NaN   $9.3 million
# 2   2015   $3.7 million         $6.8 million  $10.5 million
# 3   2016   $4.1 million         $4.9 million     $9 million
# 4   2017            NaN                  NaN            NaN
# 5   2018            NaN                  NaN            NaN
# 6   2019   $6.2 million         $2.8 million     $9 million
# 7   2020  $12.3 million         $1.3 million  $13.6 million
# 8   2021   $9.5 million         $5.2 million  $14.7 million
# 9   2022  $10.4 million         $5.6 million    $16 million
# 10  2023            NaN                  NaN            NaN

# %%
nauru = nauru.fillna(0)

# %%
nauru = nauru.drop([10])
nauru
# Out:
#    Year   Grants (USD) Grants In Kind (USD)          Total
# 0  2013   $9.3 million                    0   $9.3 million
# 1  2014   $9.3 million                    0   $9.3 million
# 2  2015   $3.7 million         $6.8 million  $10.5 million
# 3  2016   $4.1 million         $4.9 million     $9 million
# 4  2017              0                    0              0
# 5  2018              0                    0              0
# 6  2019   $6.2 million         $2.8 million     $9 million
# 7  2020  $12.3 million         $1.3 million  $13.6 million
# 8  2021   $9.5 million         $5.2 million  $14.7 million
# 9  2022  $10.4 million         $5.6 million    $16 million

# %%
nauru['grants'] = (nauru['Grants (USD)']
                   .str.replace("$","")
                   .str.replace("million","")
                  )
nauru = nauru.drop(['Grants (USD)'], axis=1)
nauru
# Out:
#    Year Grants In Kind (USD)          Total grants
# 0  2013                    0   $9.3 million   9.3
# 1  2014                    0   $9.3 million   9.3
# 2  2015         $6.8 million  $10.5 million   3.7
# 3  2016         $4.9 million     $9 million   4.1
# 4  2017                    0              0    NaN
# 5  2018                    0              0    NaN
# 6  2019         $2.8 million     $9 million   6.2
# 7  2020         $1.3 million  $13.6 million  12.3
# 8  2021         $5.2 million  $14.7 million   9.5
# 9  2022         $5.6 million    $16 million  10.4

# %%
nauru['grants-in-kind'] = (nauru['Grants In Kind (USD)']
                   .str.replace("$","")
                   .str.replace("million","")
                  )
nauru = nauru.drop(['Grants In Kind (USD)'], axis=1)
nauru['total'] = (nauru['Total']
                   .str.replace("$","")
                   .str.replace("million","")
                  )
nauru = nauru.drop(['Total'], axis=1)
nauru = nauru.fillna(0)
nauru
# Out:
#    Year grants grants-in-kind  total
# 0  2013   9.3               0   9.3
# 1  2014   9.3               0   9.3
# 2  2015   3.7            6.8   10.5
# 3  2016   4.1            4.9      9
# 4  2017      0              0      0
# 5  2018      0              0      0
# 6  2019   6.2            2.8      9
# 7  2020  12.3            1.3   13.6
# 8  2021   9.5            5.2   14.7
# 9  2022  10.4            5.6     16

# %%
nauru['country'] = 'nauru'
nauru
# Out:
#    Year grants grants-in-kind  total country
# 0  2013   9.3               0   9.3    nauru
# 1  2014   9.3               0   9.3    nauru
# 2  2015   3.7            6.8   10.5    nauru
# 3  2016   4.1            4.9      9    nauru
# 4  2017      0              0      0   nauru
# 5  2018      0              0      0   nauru
# 6  2019   6.2            2.8      9    nauru
# 7  2020  12.3            1.3   13.6    nauru
# 8  2021   9.5            5.2   14.7    nauru
# 9  2022  10.4            5.6     16    nauru

# %%
nauru.to_csv('nauru-clean.csv')

# %%
nauru_pivot = nauru.pivot(index='country', columns = 'Year', values = 'total')
nauru_pivot
# Out:
# Year     2013  2014   2015 2016 2017 2018 2019   2020   2021 2022
# country
# nauru    9.3   9.3   10.5    9     0    0   9   13.6   14.7   16

# %%
marshall['country'] = 'marshall'

# %%
marshall_pivot = marshall.pivot(index='country', columns = 'Year', values = 'total')
marshall_pivot = marshall_pivot
marshall_pivot
# Out:
# Year      2013  2014  2015  2016  2017  2018  2019  2020  2021  2022
# country
# marshall   0.0   0.0  11.0  11.0  11.0  11.0  13.0   8.0   8.0  12.0

# %%
tuvalu = pd.read_csv('tuvalu-taiwan.csv')
tuvalu
# Out:
#     Year           AUD           USD                  Notes
# 0   2013  $5.2 million  $5.4 million      Based on 'Actual'
# 1   2014    $7 million  $6.3 million    Based on 'Forecast'
# 2   2015  $8.2 million  $6.7 million                    NaN
# 3   2016  $9.2 million  $6.8 million  Forecast of 10mil AUD
# 4   2017  $8.3 million  $6.6 million                    NaN
# 5   2018  $8.5 million    $7 million                    NaN
# 6   2019  $8.7 million  $6.1 million                    NaN
# 7   2020  $9.9 million  $6.8 million                    NaN
# 8   2021  $9.5 million  $6.7 million     Forecast from 2020
# 9   2022  $9.2 million  $6.5 million     Forecast from 2020
# 10  2023           NaN           NaN                    NaN

# %%
# tuvalu['total'] = (tuvalu['USD']
#                    .str.replace("$","")
#                    .str.replace("million","")
#                   )
# tuvalu = tuvalu.drop(['USD'], axis=1)
tuvalu = tuvalu.drop(['Notes'], axis=1)
tuvalu = tuvalu.drop(['AUD'], axis=1)
tuvalu['country'] = 'tuvalu'
tuvalu = tuvalu.fillna(0)
tuvalu
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 6
#       1 # tuvalu['total'] = (tuvalu['USD']
#       2 #                    .str.replace("$","")
#       3 #                    .str.replace("million","")
#       4 #                   )
#       5 # tuvalu = tuvalu.drop(['USD'], axis=1)
# ----> 6 tuvalu = tuvalu.drop(['Notes'], axis=1)
#       7 tuvalu = tuvalu.drop(['AUD'], axis=1)
#       8 tuvalu['country'] = 'tuvalu'
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexes/base.py:6696, in Index.drop(self, labels, errors)
#    6694 if mask.any():
#    6695     if errors != "ignore":
# -> 6696         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6697     indexer = indexer[~mask]
#    6698 return self.delete(indexer)
#
# KeyError: "['Notes'] not found in axis"

# %%
tuvalu['country'] = 'tuvalu'
tuvalu = tuvalu.fillna(0)
tuvalu = tuvalu.drop([10])
tuvalu
# Out:
#    Year total country
# 0  2013  5.4   tuvalu
# 1  2014  6.3   tuvalu
# 2  2015  6.7   tuvalu
# 3  2016  6.8   tuvalu
# 4  2017  6.6   tuvalu
# 5  2018    7   tuvalu
# 6  2019  6.1   tuvalu
# 7  2020  6.8   tuvalu
# 8  2021  6.7   tuvalu
# 9  2022  6.5   tuvalu

# %%
tuvalu.to_csv('tuvalu-clean.csv')

# %%
tuvalu_pivot = tuvalu.pivot(index='country', columns = 'Year', values = 'total')
tuvalu_pivot
# Out:
# Year     2013  2014  2015  2016  2017 2018  2019  2020  2021  2022
# country
# tuvalu   5.4   6.3   6.7   6.8   6.6    7   6.1   6.8   6.7   6.5
